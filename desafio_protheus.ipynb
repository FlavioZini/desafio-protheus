# %% [markdown]
# Desafio Protheus
#
#
# 1.   Instala o pacote FPDF no ambiente ***Python***

# %%
# !pip install fpdf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fpdf in /usr/local/lib/python3.9/dist-packages (1.7.2)

# %% [markdown]
# 2.   Importa as bibliotecas necessárias para o projeto

# %%
import sqlite3
import requests
import json
from datetime import datetime
from fpdf import FPDF

# %% [markdown]
# 3.   Cria uma conexão com o banco de dados ***desafio_protheus.bd*** e cria as tabelas:

# %%
# Cria uma conexão com o banco de dados desafio_protheus.bd
conn = sqlite3.connect('desafio_protheus.bd')

# Cria a tabela Acao no BD
cursor = conn.cursor()
cursor.execute('''
    CREATE TABLE IF NOT EXISTS Acao (
        idAcao INTEGER PRIMARY KEY,
        simbolo TEXT,
        nome TEXT
    )
''')

# Cria a tabela Cotacao no BD
cursor.execute('''
    CREATE TABLE IF NOT EXISTS Cotacao (
        idAcao INTEGER,
        idCotacao INTEGER PRIMARY KEY,
        Cotacao FLOAT,
        ValorMercado FLOAT,
        VolumeTransacoes FLOAT,
        Moeda TEXT,
        Data DATETIME,
        FOREIGN KEY (idAcao) REFERENCES Acao(idAcao)
    )
''')

# %% [markdown]
# 4.   Faz o download da lista de ações disponíveis na ***API***

# %%
# URL da API
url = 'https://brapi.dev/api/available'

# Faz a solicitação GET
response = requests.get(url)

# Verifica se a resposta foi bem-sucedida
if response.status_code != 200:
    print('Erro ao conectar na API')
    exit()

# Converte a resposta para um objeto Python
data = json.loads(response.text)

# Cria um objeto Python com as siglas
siglas = {'siglas': data['stocks']}

# Escreve o objeto Python em um arquivo JSON
with open('siglas.json', 'w') as f:
    json.dump(siglas, f)
print('---------------------------------')
print('|Siglas armazenadas com sucesso!|')
print('---------------------------------')
# Out:
# ---------------------------------
# |Siglas armazenadas com sucesso!|
# ---------------------------------

# %% [markdown]
# 5.   Faz uma solicitação GET para a API da ***brapi.dev*** para cada sigla presente no arquivo ***siglas.json***

# %%
# Função para inserir os dados da cotação no banco de dados
def inserir_cotacao_bd(simbolo, nome, cotacao, valor_mercado, volume_transacoes, moeda, data):
    conn = sqlite3.connect('desafio_protheus.bd')
    cursor = conn.cursor()
    
    # Verificar se já existe uma entrada com o mesmo idAcao e Data
    cursor.execute("SELECT idCotacao FROM Cotacao JOIN Acao ON Cotacao.idAcao = Acao.idAcao WHERE Acao.simbolo = ? AND Cotacao.Data = ?", (simbolo, data))
    resultado = cursor.fetchone()
    
    if resultado:
        # Se já existe, atualizar os valores
        id_cotacao = resultado[0]
        cursor.execute("UPDATE Cotacao SET Cotacao=?, ValorMercado=?, VolumeTransacoes=?, Moeda=? WHERE idCotacao=?", (cotacao, valor_mercado, volume_transacoes, moeda, id_cotacao))
        print(f'{simbolo} atualizado com sucesso!')
    else:
        # Se não existe, inserir uma nova linha
        cursor.execute("INSERT INTO Acao (simbolo, nome) VALUES (?, ?)", (simbolo, nome))
        id_acao = cursor.lastrowid
        cursor.execute("INSERT INTO Cotacao (idAcao, Cotacao, ValorMercado, VolumeTransacoes, Moeda, Data) VALUES (?, ?, ?, ?, ?, ?)",
                        (id_acao, cotacao, valor_mercado, volume_transacoes, moeda, data))
        print(f'{simbolo} inserido com sucesso!')
    
    conn.commit()
    conn.close()

# URL da API
url_base = 'https://brapi.dev/api/'

total_siglas = len(siglas)
contador = 0

# Faz a solicitação GET para cada sigla no dicionário "siglas"
with open('siglas.json') as f:
    siglas = json.load(f)['siglas']
    for sigla in siglas:
        contador += 1
        url = url_base + 'quote/' + sigla
        response = requests.get(url)
        if response.status_code == 200:
            data = json.loads(response.text)['results'][0]
            simbolo = data.get('symbol')
            nome = data.get('shortName')
            cotacao = data.get('regularMarketPrice')
            valor_mercado = data.get('marketCap')
            volume_transacoes = data.get('regularMarketVolume')
            moeda = data.get('currency')
            data = datetime.fromisoformat(data['regularMarketTime'][:-1]).strftime('%Y-%m-%d %H:%M:%S')
            inserir_cotacao_bd(simbolo, nome, cotacao, valor_mercado, volume_transacoes, moeda, data)
            print(f'{simbolo} inserido com sucesso!')
        else:
            print(f'Erro ao consultar {sigla}')
# Out:
# HAPV3 inserido com sucesso!
# HAPV3 inserido com sucesso!
# MGLU3 inserido com sucesso!
# MGLU3 inserido com sucesso!
# FNAM11 inserido com sucesso!
# FNAM11 inserido com sucesso!
# VIIA3 inserido com sucesso!
# VIIA3 inserido com sucesso!
# BBDC4 inserido com sucesso!
# BBDC4 inserido com sucesso!
# ELET3 inserido com sucesso!
# ELET3 inserido com sucesso!
# PETR4 inserido com sucesso!
# PETR4 inserido com sucesso!
# B3SA3 inserido com sucesso!
# B3SA3 inserido com sucesso!
# VALE3 inserido com sucesso!
# VALE3 inserido com sucesso!
# ABEV3 inserido com sucesso!
# ABEV3 inserido com sucesso!
# NTCO3 inserido com sucesso!
# NTCO3 inserido com sucesso!
# MRVE3 inserido com sucesso!
# MRVE3 inserido com sucesso!
# LIGT3 inserido com sucesso!
# LIGT3 inserido com sucesso!
# LREN3 inserido com sucesso!
# LREN3 inserido com sucesso!
# COGN3 inserido com sucesso!
# COGN3 inserido com sucesso!
# ITUB4 inserido com sucesso!
# ITUB4 inserido com sucesso!
# CMIG4 inserido com sucesso!
# CMIG4 inserido com sucesso!
# AMER3 inserido com sucesso!
# AMER3 inserido com sucesso!
# USIM5 inserido com sucesso!
# USIM5 inserido com sucesso!
# ENGI11 inserido com sucesso!
# ENGI11 inserido com sucesso!
# AESB3 inserido com sucesso!
# AESB3 inserido com sucesso!
# CIEL3 inserido com sucesso!
# CIEL3 inserido com sucesso!
# CVCB3 inserido com sucesso!
# CVCB3 inserido com sucesso!
# ITSA4 inserido com sucesso!
# ITSA4 inserido com sucesso!
# CASH3 inserido com sucesso!
# CASH3 inserido com sucesso!
# BEEF3 inserido com sucesso!
# BEEF3 inserido com sucesso!
# PETZ3 inserido com sucesso!
# PETZ3 inserido com sucesso!
# ASAI3 inserido com sucesso!
# ASAI3 inserido com sucesso!
# BRFS3 inserido com sucesso!
# BRFS3 inserido com sucesso!
# CRFB3 inserido com sucesso!
# CRFB3 inserido com sucesso!
# RAIZ4 inserido com sucesso!
# RAIZ4 inserido com sucesso!
# MEGA3 inserido com sucesso!
# MEGA3 inserido com sucesso!
# AZUL4 inserido com sucesso!
# AZUL4 inserido com sucesso!
# UGPA3 inserido com sucesso!
# UGPA3 inserido com sucesso!
# NEOE3 inserido com sucesso!
# NEOE3 inserido com sucesso!
# RAIL3 inserido com sucesso!
# RAIL3 inserido com sucesso!
# BBAS3 inserido com sucesso!
# BBAS3 inserido com sucesso!
# CCRO3 inserido com sucesso!
# CCRO3 inserido com sucesso!
# GGBR4 inserido com sucesso!
# GGBR4 inserido com sucesso!
# WEGE3 inserido com sucesso!
# WEGE3 inserido com sucesso!
# MRFG3 inserido com sucesso!
# MRFG3 inserido com sucesso!
# RDOR3 inserido com sucesso!
# RDOR3 inserido com sucesso!
# GOLL4 inserido com sucesso!
# GOLL4 inserido com sucesso!
# JBSS3 inserido com sucesso!
# JBSS3 inserido com sucesso!
# RENT3 inserido com sucesso!
# RENT3 inserido com sucesso!
# LWSA3 inserido com sucesso!
# LWSA3 inserido com sucesso!
# AMAR3 inserido com sucesso!
# AMAR3 inserido com sucesso!
# SOMA3 inserido com sucesso!
# SOMA3 inserido com sucesso!
# CPLE6 inserido com sucesso!
# CPLE6 inserido com sucesso!
# PRIO3 inserido com sucesso!
# PRIO3 inserido com sucesso!
# ANIM3 inserido com sucesso!
# ANIM3 inserido com sucesso!
# PGMN3 inserido com sucesso!
# PGMN3 inserido com sucesso!
# PETR3 inserido com sucesso!
# PETR3 inserido com sucesso!
# RRRP3 inserido com sucesso!
# RRRP3 inserido com sucesso!
# BOVA11 inserido com sucesso!
# BOVA11 inserido com sucesso!
# CSNA3 inserido com sucesso!
# CSNA3 inserido com sucesso!
# VBBR3 inserido com sucesso!
# VBBR3 inserido com sucesso!
# BPAC11 inserido com sucesso!
# BPAC11 inserido com sucesso!
# EQTL3 inserido com sucesso!
# EQTL3 inserido com sucesso!
# TIMS3 inserido com sucesso!
# TIMS3 inserido com sucesso!
# ALSO3 inserido com sucesso!
# ALSO3 inserido com sucesso!
# AERI3 inserido com sucesso!
# AERI3 inserido com sucesso!
# MLAS3 inserido com sucesso!
# MLAS3 inserido com sucesso!
# EMBR3 inserido com sucesso!
# EMBR3 inserido com sucesso!
# ELET6 inserido com sucesso!
# ELET6 inserido com sucesso!
# BBDC3 inserido com sucesso!
# BBDC3 inserido com sucesso!
# CMIN3 inserido com sucesso!
# CMIN3 inserido com sucesso!
# CURY3 inserido com sucesso!
# CURY3 inserido com sucesso!
# OIBR3 inserido com sucesso!
# OIBR3 inserido com sucesso!
# RADL3 inserido com sucesso!
# RADL3 inserido com sucesso!
# CYRE3 inserido com sucesso!
# CYRE3 inserido com sucesso!
# SEQL3 inserido com sucesso!
# SEQL3 inserido com sucesso!
# ECOR3 inserido com sucesso!
# ECOR3 inserido com sucesso!
# ENEV3 inserido com sucesso!
# ENEV3 inserido com sucesso!
# SUZB3 inserido com sucesso!
# SUZB3 inserido com sucesso!
# POMO4 inserido com sucesso!
# POMO4 inserido com sucesso!
# AURE3 inserido com sucesso!
# AURE3 inserido com sucesso!
# QUAL3 inserido com sucesso!
# QUAL3 inserido com sucesso!
# DXCO3 inserido com sucesso!
# DXCO3 inserido com sucesso!
# ALPA4 inserido com sucesso!
# ALPA4 inserido com sucesso!
# KLBN4 inserido com sucesso!
# KLBN4 inserido com sucesso!
# CEAB3 inserido com sucesso!
# CEAB3 inserido com sucesso!
# GOAU4 inserido com sucesso!
# GOAU4 inserido com sucesso!
# EZTC3 inserido com sucesso!
# EZTC3 inserido com sucesso!
# BRKM5 inserido com sucesso!
# BRKM5 inserido com sucesso!
# HYPE3 inserido com sucesso!
# HYPE3 inserido com sucesso!
# LJQQ3 inserido com sucesso!
# LJQQ3 inserido com sucesso!
# KLBN11 inserido com sucesso!
# KLBN11 inserido com sucesso!
# TOTS3 inserido com sucesso!
# TOTS3 inserido com sucesso!
# BBSE3 inserido com sucesso!
# BBSE3 inserido com sucesso!
# PCAR3 inserido com sucesso!
# PCAR3 inserido com sucesso!
# STBP3 inserido com sucesso!
# STBP3 inserido com sucesso!
# RAPT4 inserido com sucesso!
# RAPT4 inserido com sucesso!
# MOVI3 inserido com sucesso!
# MOVI3 inserido com sucesso!
# YDUQ3 inserido com sucesso!
# YDUQ3 inserido com sucesso!
# ENBR3 inserido com sucesso!
# ENBR3 inserido com sucesso!
# CSAN3 inserido com sucesso!
# CSAN3 inserido com sucesso!
# SBSP3 inserido com sucesso!
# SBSP3 inserido com sucesso!
# ESPA3 inserido com sucesso!
# ESPA3 inserido com sucesso!
# GMAT3 inserido com sucesso!
# GMAT3 inserido com sucesso!
# RCSL4 inserido com sucesso!
# RCSL4 inserido com sucesso!
# DIRR3 inserido com sucesso!
# DIRR3 inserido com sucesso!
# HBSA3 inserido com sucesso!
# HBSA3 inserido com sucesso!
# PSSA3 inserido com sucesso!
# PSSA3 inserido com sucesso!
# TEND3 inserido com sucesso!
# TEND3 inserido com sucesso!
# ENJU3 inserido com sucesso!
# ENJU3 inserido com sucesso!
# TSLA34 inserido com sucesso!
# TSLA34 inserido com sucesso!
# CPFE3 inserido com sucesso!
# CPFE3 inserido com sucesso!
# MULT3 inserido com sucesso!
# MULT3 inserido com sucesso!
# IGTI11 inserido com sucesso!
# IGTI11 inserido com sucesso!
# GRND3 inserido com sucesso!
# GRND3 inserido com sucesso!
# IRBR3 inserido com sucesso!
# IRBR3 inserido com sucesso!
# SIMH3 inserido com sucesso!
# SIMH3 inserido com sucesso!
# JHSF3 inserido com sucesso!
# JHSF3 inserido com sucesso!
# BRAP4 inserido com sucesso!
# BRAP4 inserido com sucesso!
# SBFG3 inserido com sucesso!
# SBFG3 inserido com sucesso!
# BPAN4 inserido com sucesso!
# BPAN4 inserido com sucesso!
# ALUP11 inserido com sucesso!
# ALUP11 inserido com sucesso!
# PLPL3 inserido com sucesso!
# PLPL3 inserido com sucesso!
# CBAV3 inserido com sucesso!
# CBAV3 inserido com sucesso!
# VIVR3 inserido com sucesso!
# VIVR3 inserido com sucesso!
# VAMO3 inserido com sucesso!
# VAMO3 inserido com sucesso!
# SANB11 inserido com sucesso!
# SANB11 inserido com sucesso!
# MODL3 inserido com sucesso!
# MODL3 inserido com sucesso!
# NUBR33 inserido com sucesso!
# NUBR33 inserido com sucesso!
# POSI3 inserido com sucesso!
# POSI3 inserido com sucesso!
# VIVA3 inserido com sucesso!
# VIVA3 inserido com sucesso!
# RECV3 inserido com sucesso!
# RECV3 inserido com sucesso!
# CXSE3 inserido com sucesso!
# CXSE3 inserido com sucesso!
# FLRY3 inserido com sucesso!
# FLRY3 inserido com sucesso!
# EGIE3 inserido com sucesso!
# EGIE3 inserido com sucesso!
# CSMG3 inserido com sucesso!
# CSMG3 inserido com sucesso!
# ENAT3 inserido com sucesso!
# ENAT3 inserido com sucesso!
# TAEE11 inserido com sucesso!
# TAEE11 inserido com sucesso!
# SMAL11 inserido com sucesso!
# SMAL11 inserido com sucesso!
# ARZZ3 inserido com sucesso!
# ARZZ3 inserido com sucesso!
# MYPK3 inserido com sucesso!
# MYPK3 inserido com sucesso!
# GUAR3 inserido com sucesso!
# GUAR3 inserido com sucesso!
# GGPS3 inserido com sucesso!
# GGPS3 inserido com sucesso!
# KEPL3 inserido com sucesso!
# KEPL3 inserido com sucesso!
# GFSA3 inserido com sucesso!
# GFSA3 inserido com sucesso!
# MDIA3 inserido com sucesso!
# MDIA3 inserido com sucesso!
# ODPV3 inserido com sucesso!
# ODPV3 inserido com sucesso!
# NASD11 inserido com sucesso!
# NASD11 inserido com sucesso!
# DASA3 inserido com sucesso!
# DASA3 inserido com sucesso!
# RCSL3 inserido com sucesso!
# RCSL3 inserido com sucesso!
# CAML3 inserido com sucesso!
# CAML3 inserido com sucesso!
# TRPL4 inserido com sucesso!
# TRPL4 inserido com sucesso!
# VIVT3 inserido com sucesso!
# VIVT3 inserido com sucesso!
# GOLD11 inserido com sucesso!
# GOLD11 inserido com sucesso!
# ZAMP3 inserido com sucesso!
# ZAMP3 inserido com sucesso!
# SAPR4 inserido com sucesso!
# SAPR4 inserido com sucesso!
# BLAU3 inserido com sucesso!
# BLAU3 inserido com sucesso!
# BOVV11 inserido com sucesso!
# BOVV11 inserido com sucesso!
# SMTO3 inserido com sucesso!
# SMTO3 inserido com sucesso!
# KLBN3 inserido com sucesso!
# KLBN3 inserido com sucesso!
# MEAL3 inserido com sucesso!
# MEAL3 inserido com sucesso!
# IFCM3 inserido com sucesso!
# IFCM3 inserido com sucesso!
# TTEN3 inserido com sucesso!
# TTEN3 inserido com sucesso!
# SLCE3 inserido com sucesso!
# SLCE3 inserido com sucesso!
# TRAD3 inserido com sucesso!
# TRAD3 inserido com sucesso!
# SQIA3 inserido com sucesso!
# SQIA3 inserido com sucesso!
# B5MB11 inserido com sucesso!
# B5MB11 inserido com sucesso!
# ONCO3 inserido com sucesso!
# ONCO3 inserido com sucesso!
# BRSR6 inserido com sucesso!
# BRSR6 inserido com sucesso!
# INTB3 inserido com sucesso!
# INTB3 inserido com sucesso!
# RANI3 inserido com sucesso!
# RANI3 inserido com sucesso!
# MBLY3 inserido com sucesso!
# MBLY3 inserido com sucesso!
# PTBL3 inserido com sucesso!
# PTBL3 inserido com sucesso!
# BOVX11 inserido com sucesso!
# BOVX11 inserido com sucesso!
# INBR32 inserido com sucesso!
# INBR32 inserido com sucesso!
# SMFT3 inserido com sucesso!
# SMFT3 inserido com sucesso!
# SAPR11 inserido com sucesso!
# SAPR11 inserido com sucesso!
# HBOR3 inserido com sucesso!
# HBOR3 inserido com sucesso!
# ROMI3 inserido com sucesso!
# ROMI3 inserido com sucesso!
# MXRF11 inserido com sucesso!
# MXRF11 inserido com sucesso!
# MILS3 inserido com sucesso!
# MILS3 inserido com sucesso!
# LUPA3 inserido com sucesso!
# LUPA3 inserido com sucesso!
# TUPY3 inserido com sucesso!
# TUPY3 inserido com sucesso!
# BOAS3 inserido com sucesso!
# BOAS3 inserido com sucesso!
# AMBP3 inserido com sucesso!
# AMBP3 inserido com sucesso!
# JSLG3 inserido com sucesso!
# JSLG3 inserido com sucesso!
# INEP3 inserido com sucesso!
# INEP3 inserido com sucesso!
# IVVB11 inserido com sucesso!
# IVVB11 inserido com sucesso!
# PNVL3 inserido com sucesso!
# PNVL3 inserido com sucesso!
# TRIS3 inserido com sucesso!
# TRIS3 inserido com sucesso!
# XINA11 inserido com sucesso!
# XINA11 inserido com sucesso!
# EURP11 inserido com sucesso!
# EURP11 inserido com sucesso!
# CPLE3 inserido com sucesso!
# CPLE3 inserido com sucesso!
# MELI34 inserido com sucesso!
# MELI34 inserido com sucesso!
# ARML3 inserido com sucesso!
# ARML3 inserido com sucesso!
# NGRD3 inserido com sucesso!
# NGRD3 inserido com sucesso!
# ALPK3 inserido com sucesso!
# ALPK3 inserido com sucesso!
# EVEN3 inserido com sucesso!
# EVEN3 inserido com sucesso!
# JALL3 inserido com sucesso!
# JALL3 inserido com sucesso!
# XPBR31 inserido com sucesso!
# XPBR31 inserido com sucesso!
# ORVR3 inserido com sucesso!
# ORVR3 inserido com sucesso!
# ITUB3 inserido com sucesso!
# ITUB3 inserido com sucesso!
# TASA4 inserido com sucesso!
# TASA4 inserido com sucesso!
# ABCB4 inserido com sucesso!
# ABCB4 inserido com sucesso!
# BMOB3 inserido com sucesso!
# BMOB3 inserido com sucesso!
# VGIA11 inserido com sucesso!
# VGIA11 inserido com sucesso!
# WEST3 inserido com sucesso!
# WEST3 inserido com sucesso!
# BMGB4 inserido com sucesso!
# BMGB4 inserido com sucesso!
# FNOR11 inserido com sucesso!
# FNOR11 inserido com sucesso!
# AGRO3 inserido com sucesso!
# AGRO3 inserido com sucesso!
# SEER3 inserido com sucesso!
# SEER3 inserido com sucesso!
# CMIG3 inserido com sucesso!
# CMIG3 inserido com sucesso!
# VGIR11 inserido com sucesso!
# VGIR11 inserido com sucesso!
# SYNE3 inserido com sucesso!
# SYNE3 inserido com sucesso!
# UNIP6 inserido com sucesso!
# UNIP6 inserido com sucesso!
# PDGR3 inserido com sucesso!
# PDGR3 inserido com sucesso!
# KRSA3 inserido com sucesso!
# KRSA3 inserido com sucesso!
# MSFT34 inserido com sucesso!
# MSFT34 inserido com sucesso!
# HASH11 inserido com sucesso!
# HASH11 inserido com sucesso!
# LAVV3 inserido com sucesso!
# LAVV3 inserido com sucesso!
# BRIT3 inserido com sucesso!
# BRIT3 inserido com sucesso!
# SHUL4 inserido com sucesso!
# SHUL4 inserido com sucesso!
# PARD3 inserido com sucesso!
# PARD3 inserido com sucesso!
# SGPS3 inserido com sucesso!
# SGPS3 inserido com sucesso!
# VLID3 inserido com sucesso!
# VLID3 inserido com sucesso!
# BABA34 inserido com sucesso!
# BABA34 inserido com sucesso!
# OPCT3 inserido com sucesso!
# OPCT3 inserido com sucesso!
# WIZC3 inserido com sucesso!
# WIZC3 inserido com sucesso!
# IFCM3F inserido com sucesso!
# IFCM3F inserido com sucesso!
# CLSA3 inserido com sucesso!
# CLSA3 inserido com sucesso!
# MELK3 inserido com sucesso!
# MELK3 inserido com sucesso!
# FRAS3 inserido com sucesso!
# FRAS3 inserido com sucesso!
# VULC3 inserido com sucesso!
# VULC3 inserido com sucesso!
# LFTS11 inserido com sucesso!
# LFTS11 inserido com sucesso!
# TAEE4 inserido com sucesso!
# TAEE4 inserido com sucesso!
# LEVE3 inserido com sucesso!
# LEVE3 inserido com sucesso!
# SAPR3 inserido com sucesso!
# SAPR3 inserido com sucesso!
# MTRE3 inserido com sucesso!
# MTRE3 inserido com sucesso!
# MDNE3 inserido com sucesso!
# MDNE3 inserido com sucesso!
# RZAG11 inserido com sucesso!
# RZAG11 inserido com sucesso!
# INEP4 inserido com sucesso!
# INEP4 inserido com sucesso!
# AALR3 inserido com sucesso!
# AALR3 inserido com sucesso!
# PRNR3 inserido com sucesso!
# PRNR3 inserido com sucesso!
# ETER3 inserido com sucesso!
# ETER3 inserido com sucesso!
# FESA4 inserido com sucesso!
# FESA4 inserido com sucesso!
# USIM3 inserido com sucesso!
# USIM3 inserido com sucesso!
# MATD3 inserido com sucesso!
# MATD3 inserido com sucesso!
# TECN3 inserido com sucesso!
# TECN3 inserido com sucesso!
# VGHF11 inserido com sucesso!
# VGHF11 inserido com sucesso!
# COCE5 inserido com sucesso!
# COCE5 inserido com sucesso!
# SHOW3 inserido com sucesso!
# SHOW3 inserido com sucesso!
# KISU11 inserido com sucesso!
# KISU11 inserido com sucesso!
# SOJA3 inserido com sucesso!
# SOJA3 inserido com sucesso!
# MCHF11 inserido com sucesso!
# MCHF11 inserido com sucesso!
# ESGU11 inserido com sucesso!
# ESGU11 inserido com sucesso!
# LOGG3 inserido com sucesso!
# LOGG3 inserido com sucesso!
# CSED3 inserido com sucesso!
# CSED3 inserido com sucesso!
# AMZO34 inserido com sucesso!
# AMZO34 inserido com sucesso!
# PFRM3 inserido com sucesso!
# PFRM3 inserido com sucesso!
# GOGL34 inserido com sucesso!
# GOGL34 inserido com sucesso!
# USAL11 inserido com sucesso!
# USAL11 inserido com sucesso!
# SANB4 inserido com sucesso!
# SANB4 inserido com sucesso!
# AZEV4 inserido com sucesso!
# AZEV4 inserido com sucesso!
# FIQE3 inserido com sucesso!
# FIQE3 inserido com sucesso!
# BIYW39 inserido com sucesso!
# BIYW39 inserido com sucesso!
# FIND11 inserido com sucesso!
# FIND11 inserido com sucesso!
# NVDC34 inserido com sucesso!
# NVDC34 inserido com sucesso!
# HCTR11 inserido com sucesso!
# HCTR11 inserido com sucesso!
# KLBN4F inserido com sucesso!
# KLBN4F inserido com sucesso!
# XPCA11 inserido com sucesso!
# XPCA11 inserido com sucesso!
# CPLE11 inserido com sucesso!
# CPLE11 inserido com sucesso!
# VITT3 inserido com sucesso!
# VITT3 inserido com sucesso!
# SANB3 inserido com sucesso!
# SANB3 inserido com sucesso!
# FHER3 inserido com sucesso!
# FHER3 inserido com sucesso!
# ACWI11 inserido com sucesso!
# ACWI11 inserido com sucesso!
# VSLH11 inserido com sucesso!
# VSLH11 inserido com sucesso!
# KNIP11 inserido com sucesso!
# KNIP11 inserido com sucesso!
# AAPL34 inserido com sucesso!
# AAPL34 inserido com sucesso!
# UTEC11 inserido com sucesso!
# UTEC11 inserido com sucesso!
# KNCR11 inserido com sucesso!
# KNCR11 inserido com sucesso!
# DEVA11 inserido com sucesso!
# DEVA11 inserido com sucesso!
# FGAA11 inserido com sucesso!
# FGAA11 inserido com sucesso!
# PORT3 inserido com sucesso!
# PORT3 inserido com sucesso!
# DESK3 inserido com sucesso!
# DESK3 inserido com sucesso!
# ITSA3 inserido com sucesso!
# ITSA3 inserido com sucesso!
# NFLX34 inserido com sucesso!
# NFLX34 inserido com sucesso!
# TFCO4 inserido com sucesso!
# TFCO4 inserido com sucesso!
# HBRE3 inserido com sucesso!
# HBRE3 inserido com sucesso!
# XPSF11 inserido com sucesso!
# XPSF11 inserido com sucesso!
# TAEE3 inserido com sucesso!
# TAEE3 inserido com sucesso!
# IRDM11 inserido com sucesso!
# IRDM11 inserido com sucesso!
# VALE3F inserido com sucesso!
# VALE3F inserido com sucesso!
# BBAS3F inserido com sucesso!
# BBAS3F inserido com sucesso!
# PINE4 inserido com sucesso!
# PINE4 inserido com sucesso!
# VVEO3 inserido com sucesso!
# VVEO3 inserido com sucesso!
# DIVO11 inserido com sucesso!
# DIVO11 inserido com sucesso!
# BBDC4F inserido com sucesso!
# BBDC4F inserido com sucesso!
# TORD11 inserido com sucesso!
# TORD11 inserido com sucesso!
# PETR4F inserido com sucesso!
# PETR4F inserido com sucesso!
# CSUD3 inserido com sucesso!
# CSUD3 inserido com sucesso!
# BEWH39 inserido com sucesso!
# BEWH39 inserido com sucesso!
# BRPR3 inserido com sucesso!
# BRPR3 inserido com sucesso!
# ESGE11 inserido com sucesso!
# ESGE11 inserido com sucesso!
# BUSM39 inserido com sucesso!
# BUSM39 inserido com sucesso!
# ITSA4F inserido com sucesso!
# ITSA4F inserido com sucesso!
# RURA11 inserido com sucesso!
# RURA11 inserido com sucesso!
# TGMA3 inserido com sucesso!
# TGMA3 inserido com sucesso!
# TGAR11 inserido com sucesso!
# TGAR11 inserido com sucesso!
# AGXY3 inserido com sucesso!
# AGXY3 inserido com sucesso!
# LOGN3 inserido com sucesso!
# LOGN3 inserido com sucesso!
# RNEW3 inserido com sucesso!
# RNEW3 inserido com sucesso!
# BIVB39 inserido com sucesso!
# BIVB39 inserido com sucesso!
# RSID3 inserido com sucesso!
# RSID3 inserido com sucesso!
# MGLU3F inserido com sucesso!
# MGLU3F inserido com sucesso!
# NINJ3 inserido com sucesso!
# NINJ3 inserido com sucesso!
# GALG11 inserido com sucesso!
# GALG11 inserido com sucesso!
# BTCI11 inserido com sucesso!
# BTCI11 inserido com sucesso!
# LPSB3 inserido com sucesso!
# LPSB3 inserido com sucesso!
# R2DF34 inserido com sucesso!
# R2DF34 inserido com sucesso!
# WHGR11 inserido com sucesso!
# WHGR11 inserido com sucesso!
# CPTS11 inserido com sucesso!
# CPTS11 inserido com sucesso!
# TPIS3 inserido com sucesso!
# TPIS3 inserido com sucesso!
# RECR11 inserido com sucesso!
# RECR11 inserido com sucesso!
# DEXP4 inserido com sucesso!
# DEXP4 inserido com sucesso!
# ARRI11 inserido com sucesso!
# ARRI11 inserido com sucesso!
# CYCR11 inserido com sucesso!
# CYCR11 inserido com sucesso!
# POMO3 inserido com sucesso!
# POMO3 inserido com sucesso!
# ALUP4 inserido com sucesso!
# ALUP4 inserido com sucesso!
# GOAU3 inserido com sucesso!
# GOAU3 inserido com sucesso!
# AAZQ11 inserido com sucesso!
# AAZQ11 inserido com sucesso!
# ELMD3 inserido com sucesso!
# ELMD3 inserido com sucesso!
# BLMR11 inserido com sucesso!
# BLMR11 inserido com sucesso!
# VCRI11 inserido com sucesso!
# VCRI11 inserido com sucesso!
# QBTC11 inserido com sucesso!
# QBTC11 inserido com sucesso!
# BFXI39 inserido com sucesso!
# BFXI39 inserido com sucesso!
# TAEE11F inserido com sucesso!
# TAEE11F inserido com sucesso!
# BCHI39 inserido com sucesso!
# BCHI39 inserido com sucesso!
# M1TA34 inserido com sucesso!
# M1TA34 inserido com sucesso!
# AURA33 inserido com sucesso!
# AURA33 inserido com sucesso!
# BCFF11 inserido com sucesso!
# BCFF11 inserido com sucesso!
# SLED4 inserido com sucesso!
# SLED4 inserido com sucesso!
# KDIF11 inserido com sucesso!
# KDIF11 inserido com sucesso!
# RNEW4 inserido com sucesso!
# RNEW4 inserido com sucesso!
# DEXP3 inserido com sucesso!
# DEXP3 inserido com sucesso!
# IBOB11 inserido com sucesso!
# IBOB11 inserido com sucesso!
# BIYE39 inserido com sucesso!
# BIYE39 inserido com sucesso!
# BTRA11 inserido com sucesso!
# BTRA11 inserido com sucesso!
# VIUR11 inserido com sucesso!
# VIUR11 inserido com sucesso!
# VSTE3 inserido com sucesso!
# VSTE3 inserido com sucesso!
# MCCI11 inserido com sucesso!
# MCCI11 inserido com sucesso!
# C1GP34 inserido com sucesso!
# C1GP34 inserido com sucesso!
# SAPR4F inserido com sucesso!
# SAPR4F inserido com sucesso!
# TCSA3 inserido com sucesso!
# TCSA3 inserido com sucesso!
# LVTC3 inserido com sucesso!
# LVTC3 inserido com sucesso!
# RDNI3F inserido com sucesso!
# RDNI3F inserido com sucesso!
# XPML11 inserido com sucesso!
# XPML11 inserido com sucesso!
# AMER3F inserido com sucesso!
# AMER3F inserido com sucesso!
# CPLE6F inserido com sucesso!
# CPLE6F inserido com sucesso!
# OIBR4 inserido com sucesso!
# OIBR4 inserido com sucesso!
# OFSA3 inserido com sucesso!
# OFSA3 inserido com sucesso!
# G2DI33 inserido com sucesso!
# G2DI33 inserido com sucesso!
# BBOV11 inserido com sucesso!
# BBOV11 inserido com sucesso!
# TRXF11 inserido com sucesso!
# TRXF11 inserido com sucesso!
# OIAG11 inserido com sucesso!
# OIAG11 inserido com sucesso!
# BTLG11 inserido com sucesso!
# BTLG11 inserido com sucesso!
# B2YN34 inserido com sucesso!
# B2YN34 inserido com sucesso!
# STOC31 inserido com sucesso!
# STOC31 inserido com sucesso!
# APER3 inserido com sucesso!
# APER3 inserido com sucesso!
# HAPV3F inserido com sucesso!
# HAPV3F inserido com sucesso!
# IRBR3F inserido com sucesso!
# IRBR3F inserido com sucesso!
# KLBN11F inserido com sucesso!
# KLBN11F inserido com sucesso!
# HGRU11 inserido com sucesso!
# HGRU11 inserido com sucesso!
# XPLG11 inserido com sucesso!
# XPLG11 inserido com sucesso!
# WEGE3F inserido com sucesso!
# WEGE3F inserido com sucesso!
# RAPT3 inserido com sucesso!
# RAPT3 inserido com sucesso!
# KLBN3F inserido com sucesso!
# KLBN3F inserido com sucesso!
# BBDC3F inserido com sucesso!
# BBDC3F inserido com sucesso!
# BRBI11 inserido com sucesso!
# BRBI11 inserido com sucesso!
# KNRI11 inserido com sucesso!
# KNRI11 inserido com sucesso!
# PRIO3F inserido com sucesso!
# PRIO3F inserido com sucesso!
# KNSC11 inserido com sucesso!
# KNSC11 inserido com sucesso!
# ATMP3 inserido com sucesso!
# ATMP3 inserido com sucesso!
# RRRP3F inserido com sucesso!
# RRRP3F inserido com sucesso!
# ALUP11F inserido com sucesso!
# ALUP11F inserido com sucesso!
# MRFG3F inserido com sucesso!
# MRFG3F inserido com sucesso!
# VIIA3F inserido com sucesso!
# VIIA3F inserido com sucesso!
# CVCB3F inserido com sucesso!
# CVCB3F inserido com sucesso!
# BBSE3F inserido com sucesso!
# BBSE3F inserido com sucesso!
# TAEE4F inserido com sucesso!
# TAEE4F inserido com sucesso!
# BBOI11 inserido com sucesso!
# BBOI11 inserido com sucesso!
# NCRA11 inserido com sucesso!
# NCRA11 inserido com sucesso!
# PVBI11 inserido com sucesso!
# PVBI11 inserido com sucesso!
# USIM5F inserido com sucesso!
# USIM5F inserido com sucesso!
# C1SU34 inserido com sucesso!
# C1SU34 inserido com sucesso!
# ALUP3 inserido com sucesso!
# ALUP3 inserido com sucesso!
# KNCA11 inserido com sucesso!
# KNCA11 inserido com sucesso!
# BRAP3 inserido com sucesso!
# BRAP3 inserido com sucesso!
# IGTI3 inserido com sucesso!
# IGTI3 inserido com sucesso!
# ITUB4F inserido com sucesso!
# ITUB4F inserido com sucesso!
# BEWZ39 inserido com sucesso!
# BEWZ39 inserido com sucesso!
# AESB3F inserido com sucesso!
# AESB3F inserido com sucesso!
# VRTA11 inserido com sucesso!
# VRTA11 inserido com sucesso!
# UNIP6F inserido com sucesso!
# UNIP6F inserido com sucesso!
# VGIP11 inserido com sucesso!
# VGIP11 inserido com sucesso!
# HGLG11 inserido com sucesso!
# HGLG11 inserido com sucesso!
# MRVE3F inserido com sucesso!
# MRVE3F inserido com sucesso!
# E1DU34 inserido com sucesso!
# E1DU34 inserido com sucesso!
# PMAM3 inserido com sucesso!
# PMAM3 inserido com sucesso!
# EMAE4 inserido com sucesso!
# EMAE4 inserido com sucesso!
# LREN3F inserido com sucesso!
# LREN3F inserido com sucesso!
# BRKM5F inserido com sucesso!
# BRKM5F inserido com sucesso!
# CVBI11 inserido com sucesso!
# CVBI11 inserido com sucesso!
# RBRR11 inserido com sucesso!
# RBRR11 inserido com sucesso!
# MATB11 inserido com sucesso!
# MATB11 inserido com sucesso!
# KNHY11 inserido com sucesso!
# KNHY11 inserido com sucesso!
# RBRF11 inserido com sucesso!
# RBRF11 inserido com sucesso!
# MALL11 inserido com sucesso!
# MALL11 inserido com sucesso!
# HAGA3 inserido com sucesso!
# HAGA3 inserido com sucesso!
# DOTZ3 inserido com sucesso!
# DOTZ3 inserido com sucesso!
# EGIE3F inserido com sucesso!
# EGIE3F inserido com sucesso!
# CXSE3F inserido com sucesso!
# CXSE3F inserido com sucesso!
# HGCR11 inserido com sucesso!
# HGCR11 inserido com sucesso!
# QETH11 inserido com sucesso!
# QETH11 inserido com sucesso!
# JSRE11 inserido com sucesso!
# JSRE11 inserido com sucesso!
# EUCA4 inserido com sucesso!
# EUCA4 inserido com sucesso!
# BRCO11 inserido com sucesso!
# BRCO11 inserido com sucesso!
# RZAK11 inserido com sucesso!
# RZAK11 inserido com sucesso!
# BRAP4F inserido com sucesso!
# BRAP4F inserido com sucesso!
# TRPL4F inserido com sucesso!
# TRPL4F inserido com sucesso!
# VISC11 inserido com sucesso!
# VISC11 inserido com sucesso!
# OIBR3F inserido com sucesso!
# OIBR3F inserido com sucesso!
# BIOM3 inserido com sucesso!
# BIOM3 inserido com sucesso!
# AMAR3F inserido com sucesso!
# AMAR3F inserido com sucesso!
# URET11 inserido com sucesso!
# URET11 inserido com sucesso!
# CMIN3F inserido com sucesso!
# CMIN3F inserido com sucesso!
# CTSA4 inserido com sucesso!
# CTSA4 inserido com sucesso!
# URPR11 inserido com sucesso!
# URPR11 inserido com sucesso!
# JBSS3F inserido com sucesso!
# JBSS3F inserido com sucesso!
# MOVI3F inserido com sucesso!
# MOVI3F inserido com sucesso!
# CASH3F inserido com sucesso!
# CASH3F inserido com sucesso!
# UNHH34 inserido com sucesso!
# UNHH34 inserido com sucesso!
# SSFO34 inserido com sucesso!
# SSFO34 inserido com sucesso!
# GRND3F inserido com sucesso!
# GRND3F inserido com sucesso!
# VBBR3F inserido com sucesso!
# VBBR3F inserido com sucesso!
# BBPO11 inserido com sucesso!
# BBPO11 inserido com sucesso!
# RZTR11 inserido com sucesso!
# RZTR11 inserido com sucesso!
# RAIZ4F inserido com sucesso!
# RAIZ4F inserido com sucesso!
# BDIF11 inserido com sucesso!
# BDIF11 inserido com sucesso!
# BEEF3F inserido com sucesso!
# BEEF3F inserido com sucesso!
# RDNI3 inserido com sucesso!
# RDNI3 inserido com sucesso!
# B5P211 inserido com sucesso!
# B5P211 inserido com sucesso!
# GGBR4F inserido com sucesso!
# GGBR4F inserido com sucesso!
# SUZB3F inserido com sucesso!
# SUZB3F inserido com sucesso!
# KEPL3F inserido com sucesso!
# KEPL3F inserido com sucesso!
# UNIP3 inserido com sucesso!
# UNIP3 inserido com sucesso!
# BEES3 inserido com sucesso!
# BEES3 inserido com sucesso!
# CMIG4F inserido com sucesso!
# CMIG4F inserido com sucesso!
# JURO11 inserido com sucesso!
# JURO11 inserido com sucesso!
# JHSF3F inserido com sucesso!
# JHSF3F inserido com sucesso!
# AZEV3 inserido com sucesso!
# AZEV3 inserido com sucesso!
# FLRY3F inserido com sucesso!
# FLRY3F inserido com sucesso!
# BRCR11 inserido com sucesso!
# BRCR11 inserido com sucesso!
# HFOF11 inserido com sucesso!
# HFOF11 inserido com sucesso!
# ESGD11 inserido com sucesso!
# ESGD11 inserido com sucesso!
# PETZ3F inserido com sucesso!
# PETZ3F inserido com sucesso!
# AZUL4F inserido com sucesso!
# AZUL4F inserido com sucesso!
# ABEV3F inserido com sucesso!
# ABEV3F inserido com sucesso!
# BRFS3F inserido com sucesso!
# BRFS3F inserido com sucesso!
# ENBR3F inserido com sucesso!
# ENBR3F inserido com sucesso!
# XMAL11 inserido com sucesso!
# XMAL11 inserido com sucesso!
# HSML11 inserido com sucesso!
# HSML11 inserido com sucesso!
# BLAU3F inserido com sucesso!
# BLAU3F inserido com sucesso!
# RBRP11 inserido com sucesso!
# RBRP11 inserido com sucesso!
# VCJR11 inserido com sucesso!
# VCJR11 inserido com sucesso!
# AGRO3F inserido com sucesso!
# AGRO3F inserido com sucesso!
# EMBR3F inserido com sucesso!
# EMBR3F inserido com sucesso!
# LVBI11 inserido com sucesso!
# LVBI11 inserido com sucesso!
# PDTC3 inserido com sucesso!
# PDTC3 inserido com sucesso!
# PGMN3F inserido com sucesso!
# PGMN3F inserido com sucesso!
# C2OI34 inserido com sucesso!
# C2OI34 inserido com sucesso!
# CSAN3F inserido com sucesso!
# CSAN3F inserido com sucesso!
# CRPG5 inserido com sucesso!
# CRPG5 inserido com sucesso!
# DISB34 inserido com sucesso!
# DISB34 inserido com sucesso!
# F2NV34 inserido com sucesso!
# F2NV34 inserido com sucesso!
# XPCI11 inserido com sucesso!
# XPCI11 inserido com sucesso!
# VIVT3F inserido com sucesso!
# VIVT3F inserido com sucesso!
# HGRE11 inserido com sucesso!
# HGRE11 inserido com sucesso!
# CEBR6 inserido com sucesso!
# CEBR6 inserido com sucesso!
# BCRI11 inserido com sucesso!
# BCRI11 inserido com sucesso!
# GTWR11 inserido com sucesso!
# GTWR11 inserido com sucesso!
# ASAI3F inserido com sucesso!
# ASAI3F inserido com sucesso!
# BODB11 inserido com sucesso!
# BODB11 inserido com sucesso!
# FIXA11 inserido com sucesso!
# FIXA11 inserido com sucesso!
# DMVF3 inserido com sucesso!
# DMVF3 inserido com sucesso!
# RDOR3F inserido com sucesso!
# RDOR3F inserido com sucesso!
# PAGS34 inserido com sucesso!
# PAGS34 inserido com sucesso!
# VILG11 inserido com sucesso!
# VILG11 inserido com sucesso!
# TIMS3F inserido com sucesso!
# TIMS3F inserido com sucesso!
# T1WL34 inserido com sucesso!
# T1WL34 inserido com sucesso!
# SARE11 inserido com sucesso!
# SARE11 inserido com sucesso!
# BIOM3F inserido com sucesso!
# BIOM3F inserido com sucesso!
# HABT11 inserido com sucesso!
# HABT11 inserido com sucesso!
# CIEL3F inserido com sucesso!
# CIEL3F inserido com sucesso!
# CAMB3F inserido com sucesso!
# CAMB3F inserido com sucesso!
# WRLD11 inserido com sucesso!
# WRLD11 inserido com sucesso!
# RANI3F inserido com sucesso!
# RANI3F inserido com sucesso!
# CRFB3F inserido com sucesso!
# CRFB3F inserido com sucesso!
# EZTC3F inserido com sucesso!
# EZTC3F inserido com sucesso!
# RZAT11 inserido com sucesso!
# RZAT11 inserido com sucesso!
# KFOF11 inserido com sucesso!
# KFOF11 inserido com sucesso!
# AURE3F inserido com sucesso!
# AURE3F inserido com sucesso!
# CSNA3F inserido com sucesso!
# CSNA3F inserido com sucesso!
# RCSL4F inserido com sucesso!
# RCSL4F inserido com sucesso!
# WIZC3F inserido com sucesso!
# WIZC3F inserido com sucesso!
# ENGI4 inserido com sucesso!
# ENGI4 inserido com sucesso!
# T1DG34 inserido com sucesso!
# T1DG34 inserido com sucesso!
# ALSO3F inserido com sucesso!
# ALSO3F inserido com sucesso!
# TAEE3F inserido com sucesso!
# TAEE3F inserido com sucesso!
# ALLD3 inserido com sucesso!
# ALLD3 inserido com sucesso!
# C1CL34 inserido com sucesso!
# C1CL34 inserido com sucesso!
# EQTL3F inserido com sucesso!
# EQTL3F inserido com sucesso!
# TASA4F inserido com sucesso!
# TASA4F inserido com sucesso!
# BERK34 inserido com sucesso!
# BERK34 inserido com sucesso!
# ITLC34 inserido com sucesso!
# ITLC34 inserido com sucesso!
# PATL11 inserido com sucesso!
# PATL11 inserido com sucesso!
# GOLL4F inserido com sucesso!
# GOLL4F inserido com sucesso!
# DCRA11 inserido com sucesso!
# DCRA11 inserido com sucesso!
# EALT4 inserido com sucesso!
# EALT4 inserido com sucesso!
# ELET3F inserido com sucesso!
# ELET3F inserido com sucesso!
# SNCI11 inserido com sucesso!
# SNCI11 inserido com sucesso!
# NTCO3F inserido com sucesso!
# NTCO3F inserido com sucesso!
# GOAU4F inserido com sucesso!
# GOAU4F inserido com sucesso!
# ENAT3F inserido com sucesso!
# ENAT3F inserido com sucesso!
# QDFI11 inserido com sucesso!
# QDFI11 inserido com sucesso!
# RBRY11 inserido com sucesso!
# RBRY11 inserido com sucesso!
# CARE11 inserido com sucesso!
# CARE11 inserido com sucesso!
# KNRE11 inserido com sucesso!
# KNRE11 inserido com sucesso!
# SPXI11 inserido com sucesso!
# SPXI11 inserido com sucesso!
# PICE11 inserido com sucesso!
# PICE11 inserido com sucesso!
# XBOV11 inserido com sucesso!
# XBOV11 inserido com sucesso!
# BMGB4F inserido com sucesso!
# BMGB4F inserido com sucesso!
# CPLE3F inserido com sucesso!
# CPLE3F inserido com sucesso!
# SANB4F inserido com sucesso!
# SANB4F inserido com sucesso!
# CPTR11 inserido com sucesso!
# CPTR11 inserido com sucesso!
# ETHE11 inserido com sucesso!
# ETHE11 inserido com sucesso!
# JNJB34 inserido com sucesso!
# JNJB34 inserido com sucesso!
# ALZR11 inserido com sucesso!
# ALZR11 inserido com sucesso!
# XFIX11 inserido com sucesso!
# XFIX11 inserido com sucesso!
# SANB11F inserido com sucesso!
# SANB11F inserido com sucesso!
# CEBR3 inserido com sucesso!
# CEBR3 inserido com sucesso!
# VINO11 inserido com sucesso!
# VINO11 inserido com sucesso!
# AERI3F inserido com sucesso!
# AERI3F inserido com sucesso!
# IFRA11 inserido com sucesso!
# IFRA11 inserido com sucesso!
# GPIV33 inserido com sucesso!
# GPIV33 inserido com sucesso!
# SANB3F inserido com sucesso!
# SANB3F inserido com sucesso!
# HGBS11 inserido com sucesso!
# HGBS11 inserido com sucesso!
# RAIL3F inserido com sucesso!
# RAIL3F inserido com sucesso!
# CHCM34 inserido com sucesso!
# CHCM34 inserido com sucesso!
# LIFE11 inserido com sucesso!
# LIFE11 inserido com sucesso!
# SAPR3F inserido com sucesso!
# SAPR3F inserido com sucesso!
# PFIN11 inserido com sucesso!
# PFIN11 inserido com sucesso!
# ROMI3F inserido com sucesso!
# ROMI3F inserido com sucesso!
# LAND3 inserido com sucesso!
# LAND3 inserido com sucesso!
# BITH11 inserido com sucesso!
# BITH11 inserido com sucesso!
# VIGT11 inserido com sucesso!
# VIGT11 inserido com sucesso!
# CTNM4 inserido com sucesso!
# CTNM4 inserido com sucesso!
# AIEC11 inserido com sucesso!
# AIEC11 inserido com sucesso!
# XPIE11 inserido com sucesso!
# XPIE11 inserido com sucesso!
# SDIL11 inserido com sucesso!
# SDIL11 inserido com sucesso!
# CRPT11 inserido com sucesso!
# CRPT11 inserido com sucesso!
# TASA3 inserido com sucesso!
# TASA3 inserido com sucesso!
# PETR3F inserido com sucesso!
# PETR3F inserido com sucesso!
# PSSA3F inserido com sucesso!
# PSSA3F inserido com sucesso!
# COWC34 inserido com sucesso!
# COWC34 inserido com sucesso!
# SBSP3F inserido com sucesso!
# SBSP3F inserido com sucesso!
# LEVE3F inserido com sucesso!
# LEVE3F inserido com sucesso!
# S2QU34 inserido com sucesso!
# S2QU34 inserido com sucesso!
# M1RN34 inserido com sucesso!
# M1RN34 inserido com sucesso!
# POSI3F inserido com sucesso!
# POSI3F inserido com sucesso!
# DIRR3F inserido com sucesso!
# DIRR3F inserido com sucesso!
# BRSR6F inserido com sucesso!
# BRSR6F inserido com sucesso!
# ALUP4F inserido com sucesso!
# ALUP4F inserido com sucesso!
# A1LB34 inserido com sucesso!
# A1LB34 inserido com sucesso!
# RCRB11 inserido com sucesso!
# RCRB11 inserido com sucesso!
# CYRE3F inserido com sucesso!
# CYRE3F inserido com sucesso!
# U2PS34 inserido com sucesso!
# U2PS34 inserido com sucesso!
# ALUG11 inserido com sucesso!
# ALUG11 inserido com sucesso!
# XPPR11 inserido com sucesso!
# XPPR11 inserido com sucesso!
# ATTB34 inserido com sucesso!
# ATTB34 inserido com sucesso!
# CPFE3F inserido com sucesso!
# CPFE3F inserido com sucesso!
# EUCA3 inserido com sucesso!
# EUCA3 inserido com sucesso!
# ALPA4F inserido com sucesso!
# ALPA4F inserido com sucesso!
# RECT11 inserido com sucesso!
# RECT11 inserido com sucesso!
# BRZP11 inserido com sucesso!
# BRZP11 inserido com sucesso!
# DHER34 inserido com sucesso!
# DHER34 inserido com sucesso!
# K2CG34 inserido com sucesso!
# K2CG34 inserido com sucesso!
# SOMA3F inserido com sucesso!
# SOMA3F inserido com sucesso!
# VIVA3F inserido com sucesso!
# VIVA3F inserido com sucesso!
# GGBR3 inserido com sucesso!
# GGBR3 inserido com sucesso!
# GGRC11 inserido com sucesso!
# GGRC11 inserido com sucesso!
# GSFI11 inserido com sucesso!
# GSFI11 inserido com sucesso!
# CEBR5 inserido com sucesso!
# CEBR5 inserido com sucesso!
# CBAV3F inserido com sucesso!
# CBAV3F inserido com sucesso!
# MGFF11 inserido com sucesso!
# MGFF11 inserido com sucesso!
# QAGR11 inserido com sucesso!
# QAGR11 inserido com sucesso!
# SAPR11F inserido com sucesso!
# SAPR11F inserido com sucesso!
# BPAC11F inserido com sucesso!
# BPAC11F inserido com sucesso!
# RENT3F inserido com sucesso!
# RENT3F inserido com sucesso!
# NEOE3F inserido com sucesso!
# NEOE3F inserido com sucesso!
# RADL3F inserido com sucesso!
# RADL3F inserido com sucesso!
# BBFO11 inserido com sucesso!
# BBFO11 inserido com sucesso!
# MANA11 inserido com sucesso!
# MANA11 inserido com sucesso!
# CAML3F inserido com sucesso!
# CAML3F inserido com sucesso!
# MRCK34 inserido com sucesso!
# MRCK34 inserido com sucesso!
# VISA34 inserido com sucesso!
# VISA34 inserido com sucesso!
# RBVA11 inserido com sucesso!
# RBVA11 inserido com sucesso!
# ARZZ3F inserido com sucesso!
# ARZZ3F inserido com sucesso!
# ITSA3F inserido com sucesso!
# ITSA3F inserido com sucesso!
# GMCO34 inserido com sucesso!
# GMCO34 inserido com sucesso!
# UCAS3 inserido com sucesso!
# UCAS3 inserido com sucesso!
# COCA34 inserido com sucesso!
# COCA34 inserido com sucesso!
# MORE11 inserido com sucesso!
# MORE11 inserido com sucesso!
# COGN3F inserido com sucesso!
# COGN3F inserido com sucesso!
# ODPV3F inserido com sucesso!
# ODPV3F inserido com sucesso!
# U1BE34 inserido com sucesso!
# U1BE34 inserido com sucesso!
# IBCR11 inserido com sucesso!
# IBCR11 inserido com sucesso!
# CPFF11 inserido com sucesso!
# CPFF11 inserido com sucesso!
# HYPE3F inserido com sucesso!
# HYPE3F inserido com sucesso!
# MDIA3F inserido com sucesso!
# MDIA3F inserido com sucesso!
# ATOM3 inserido com sucesso!
# ATOM3 inserido com sucesso!
# BTAG11 inserido com sucesso!
# BTAG11 inserido com sucesso!
# MYPK3F inserido com sucesso!
# MYPK3F inserido com sucesso!
# CCRO3F inserido com sucesso!
# CCRO3F inserido com sucesso!
# LIGT3F inserido com sucesso!
# LIGT3F inserido com sucesso!
# BRKM3 inserido com sucesso!
# BRKM3 inserido com sucesso!
# A1MD34 inserido com sucesso!
# A1MD34 inserido com sucesso!
# PCAR3F inserido com sucesso!
# PCAR3F inserido com sucesso!
# PTNT4 inserido com sucesso!
# PTNT4 inserido com sucesso!
# LWSA3F inserido com sucesso!
# LWSA3F inserido com sucesso!
# SMTO3F inserido com sucesso!
# SMTO3F inserido com sucesso!
# SLCE3F inserido com sucesso!
# SLCE3F inserido com sucesso!
# RAPT4F inserido com sucesso!
# RAPT4F inserido com sucesso!
# TSMC34 inserido com sucesso!
# TSMC34 inserido com sucesso!
# QUAL3F inserido com sucesso!
# QUAL3F inserido com sucesso!
# M1NS34 inserido com sucesso!
# M1NS34 inserido com sucesso!
# ABCB4F inserido com sucesso!
# ABCB4F inserido com sucesso!
# ENEV3F inserido com sucesso!
# ENEV3F inserido com sucesso!
# HGFF11 inserido com sucesso!
# HGFF11 inserido com sucesso!
# U2ST34 inserido com sucesso!
# U2ST34 inserido com sucesso!
# OUJP11 inserido com sucesso!
# OUJP11 inserido com sucesso!
# GAME11 inserido com sucesso!
# GAME11 inserido com sucesso!
# RECV3F inserido com sucesso!
# RECV3F inserido com sucesso!
# UGPA3F inserido com sucesso!
# UGPA3F inserido com sucesso!
# YDUQ3F inserido com sucesso!
# YDUQ3F inserido com sucesso!
# GMAT3F inserido com sucesso!
# GMAT3F inserido com sucesso!
# SNAG11 inserido com sucesso!
# SNAG11 inserido com sucesso!
# SIMH3F inserido com sucesso!
# SIMH3F inserido com sucesso!
# OGIN11 inserido com sucesso!
# OGIN11 inserido com sucesso!
# TOTS3F inserido com sucesso!
# TOTS3F inserido com sucesso!
# NEXP3 inserido com sucesso!
# NEXP3 inserido com sucesso!
# STBP3F inserido com sucesso!
# STBP3F inserido com sucesso!
# BEWU39 inserido com sucesso!
# BEWU39 inserido com sucesso!
# TMOS34 inserido com sucesso!
# TMOS34 inserido com sucesso!
# CMCS34 inserido com sucesso!
# CMCS34 inserido com sucesso!
# HSLG11 inserido com sucesso!
# HSLG11 inserido com sucesso!
# DXCO3F inserido com sucesso!
# DXCO3F inserido com sucesso!
# POMO4F inserido com sucesso!
# POMO4F inserido com sucesso!
# BIVE39 inserido com sucesso!
# BIVE39 inserido com sucesso!
# ITUB3F inserido com sucesso!
# ITUB3F inserido com sucesso!
# MLAS3F inserido com sucesso!
# MLAS3F inserido com sucesso!
# ELET6F inserido com sucesso!
# ELET6F inserido com sucesso!
# BEWG39 inserido com sucesso!
# BEWG39 inserido com sucesso!
# SNFF11 inserido com sucesso!
# SNFF11 inserido com sucesso!
# CSMG3F inserido com sucesso!
# CSMG3F inserido com sucesso!
# SHUL4F inserido com sucesso!
# SHUL4F inserido com sucesso!
# JPMC34 inserido com sucesso!
# JPMC34 inserido com sucesso!
# BARI11 inserido com sucesso!
# BARI11 inserido com sucesso!
# ALUP3F inserido com sucesso!
# ALUP3F inserido com sucesso!
# LILY34 inserido com sucesso!
# LILY34 inserido com sucesso!
# RBFF11 inserido com sucesso!
# RBFF11 inserido com sucesso!
# ALPA3 inserido com sucesso!
# ALPA3 inserido com sucesso!
# PORD11 inserido com sucesso!
# PORD11 inserido com sucesso!
# BEEM39 inserido com sucesso!
# BEEM39 inserido com sucesso!
# RBHG11 inserido com sucesso!
# RBHG11 inserido com sucesso!
# BDIV11 inserido com sucesso!
# BDIV11 inserido com sucesso!
# CURY3F inserido com sucesso!
# CURY3F inserido com sucesso!
# BROF11 inserido com sucesso!
# BROF11 inserido com sucesso!
# BACW39 inserido com sucesso!
# BACW39 inserido com sucesso!
# PFIZ34 inserido com sucesso!
# PFIZ34 inserido com sucesso!
# JDCO34 inserido com sucesso!
# JDCO34 inserido com sucesso!
# AMBP3F inserido com sucesso!
# AMBP3F inserido com sucesso!
# TRIS3F inserido com sucesso!
# TRIS3F inserido com sucesso!
# VERZ34 inserido com sucesso!
# VERZ34 inserido com sucesso!
# AGRX11 inserido com sucesso!
# AGRX11 inserido com sucesso!
# JSAF11 inserido com sucesso!
# JSAF11 inserido com sucesso!
# BIME11 inserido com sucesso!
# BIME11 inserido com sucesso!
# USIM3F inserido com sucesso!
# USIM3F inserido com sucesso!
# ECOR3F inserido com sucesso!
# ECOR3F inserido com sucesso!
# BEFG39 inserido com sucesso!
# BEFG39 inserido com sucesso!
# AXPB34 inserido com sucesso!
# AXPB34 inserido com sucesso!
# SQIA3F inserido com sucesso!
# SQIA3F inserido com sucesso!
# BCIA11 inserido com sucesso!
# BCIA11 inserido com sucesso!
# BAER39 inserido com sucesso!
# BAER39 inserido com sucesso!
# TUPY3F inserido com sucesso!
# TUPY3F inserido com sucesso!
# BSHV39 inserido com sucesso!
# BSHV39 inserido com sucesso!
# CPTI11 inserido com sucesso!
# CPTI11 inserido com sucesso!
# BEWJ39 inserido com sucesso!
# BEWJ39 inserido com sucesso!
# CORN11 inserido com sucesso!
# CORN11 inserido com sucesso!
# TEPP11 inserido com sucesso!
# TEPP11 inserido com sucesso!
# R1KU34 inserido com sucesso!
# R1KU34 inserido com sucesso!
# IGTI11F inserido com sucesso!
# IGTI11F inserido com sucesso!
# ENDD11 inserido com sucesso!
# ENDD11 inserido com sucesso!
# VAMO3F inserido com sucesso!
# VAMO3F inserido com sucesso!
# BBGO11 inserido com sucesso!
# BBGO11 inserido com sucesso!
# BSLV39 inserido com sucesso!
# BSLV39 inserido com sucesso!
# Z1OM34 inserido com sucesso!
# Z1OM34 inserido com sucesso!
# ENGI11F inserido com sucesso!
# ENGI11F inserido com sucesso!
# PEPB34 inserido com sucesso!
# PEPB34 inserido com sucesso!
# BTAL11 inserido com sucesso!
# BTAL11 inserido com sucesso!
# CAMB3 inserido com sucesso!
# CAMB3 inserido com sucesso!
# BPAN4F inserido com sucesso!
# BPAN4F inserido com sucesso!
# PNVL3F inserido com sucesso!
# PNVL3F inserido com sucesso!
# SMAC11 inserido com sucesso!
# SMAC11 inserido com sucesso!
# SADI11 inserido com sucesso!
# SADI11 inserido com sucesso!
# BEFA39 inserido com sucesso!
# BEFA39 inserido com sucesso!
# OSXB3 inserido com sucesso!
# OSXB3 inserido com sucesso!
# MULT3F inserido com sucesso!
# MULT3F inserido com sucesso!
# EXXO34 inserido com sucesso!
# EXXO34 inserido com sucesso!
# OUFF11 inserido com sucesso!
# OUFF11 inserido com sucesso!
# FESA4F inserido com sucesso!
# FESA4F inserido com sucesso!
# REDE3 inserido com sucesso!
# REDE3 inserido com sucesso!
# RBRX11 inserido com sucesso!
# RBRX11 inserido com sucesso!
# CLSC4 inserido com sucesso!
# CLSC4 inserido com sucesso!
# TTEN3F inserido com sucesso!
# TTEN3F inserido com sucesso!
# CEOC11 inserido com sucesso!
# CEOC11 inserido com sucesso!
# KNOX11 inserido com sucesso!
# KNOX11 inserido com sucesso!
# BEES3F inserido com sucesso!
# BEES3F inserido com sucesso!
# SNSY5 inserido com sucesso!
# SNSY5 inserido com sucesso!
# SLED3 inserido com sucesso!
# SLED3 inserido com sucesso!
# S2EA34 inserido com sucesso!
# S2EA34 inserido com sucesso!
# GFSA3F inserido com sucesso!
# GFSA3F inserido com sucesso!
# RCSL3F inserido com sucesso!
# RCSL3F inserido com sucesso!
# AFHI11 inserido com sucesso!
# AFHI11 inserido com sucesso!
# BQUA39 inserido com sucesso!
# BQUA39 inserido com sucesso!
# UNIP3F inserido com sucesso!
# UNIP3F inserido com sucesso!
# CEAB3F inserido com sucesso!
# CEAB3F inserido com sucesso!
# RVBI11 inserido com sucesso!
# RVBI11 inserido com sucesso!
# RIOT34 inserido com sucesso!
# RIOT34 inserido com sucesso!
# VCRA11 inserido com sucesso!
# VCRA11 inserido com sucesso!
# JALL3F inserido com sucesso!
# JALL3F inserido com sucesso!
# CGRA4 inserido com sucesso!
# CGRA4 inserido com sucesso!
# WLMM4 inserido com sucesso!
# WLMM4 inserido com sucesso!
# CACR11 inserido com sucesso!
# CACR11 inserido com sucesso!
# SEQL3F inserido com sucesso!
# SEQL3F inserido com sucesso!
# RBRL11 inserido com sucesso!
# RBRL11 inserido com sucesso!
# HAGA4 inserido com sucesso!
# HAGA4 inserido com sucesso!
# ANIM3F inserido com sucesso!
# ANIM3F inserido com sucesso!
# RELG11 inserido com sucesso!
# RELG11 inserido com sucesso!
# WEB311 inserido com sucesso!
# WEB311 inserido com sucesso!
# WHRL4 inserido com sucesso!
# WHRL4 inserido com sucesso!
# XPIN11 inserido com sucesso!
# XPIN11 inserido com sucesso!
# ELCI34 inserido com sucesso!
# ELCI34 inserido com sucesso!
# ENJU3F inserido com sucesso!
# ENJU3F inserido com sucesso!
# SYNE3F inserido com sucesso!
# SYNE3F inserido com sucesso!
# DEFI11 inserido com sucesso!
# DEFI11 inserido com sucesso!
# XPID11 inserido com sucesso!
# XPID11 inserido com sucesso!
# KCRE11 inserido com sucesso!
# KCRE11 inserido com sucesso!
# BMOB3F inserido com sucesso!
# BMOB3F inserido com sucesso!
# SBFG3F inserido com sucesso!
# SBFG3F inserido com sucesso!
# AVLL3 inserido com sucesso!
# AVLL3 inserido com sucesso!
# RNEW11 inserido com sucesso!
# RNEW11 inserido com sucesso!
# BLMG11 inserido com sucesso!
# BLMG11 inserido com sucesso!
# FSRF11F inserido com sucesso!
# FSRF11F inserido com sucesso!
# T1AL34 inserido com sucesso!
# T1AL34 inserido com sucesso!
# BMMT11 inserido com sucesso!
# BMMT11 inserido com sucesso!
# MSCD34 inserido com sucesso!
# MSCD34 inserido com sucesso!
# CMIG3F inserido com sucesso!
# CMIG3F inserido com sucesso!
# TEND3F inserido com sucesso!
# TEND3F inserido com sucesso!
# NCHB11 inserido com sucesso!
# NCHB11 inserido com sucesso!
# PDGR3F inserido com sucesso!
# PDGR3F inserido com sucesso!
# BAZA3 inserido com sucesso!
# BAZA3 inserido com sucesso!
# PLCR11 inserido com sucesso!
# PLCR11 inserido com sucesso!
# MORC11 inserido com sucesso!
# MORC11 inserido com sucesso!
# TRPL3 inserido com sucesso!
# TRPL3 inserido com sucesso!
# SCAR3 inserido com sucesso!
# SCAR3 inserido com sucesso!
# BMEB4 inserido com sucesso!
# BMEB4 inserido com sucesso!
# PLPL3F inserido com sucesso!
# PLPL3F inserido com sucesso!
# BOVB11 inserido com sucesso!
# BOVB11 inserido com sucesso!
# TECN3F inserido com sucesso!
# TECN3F inserido com sucesso!
# BIBB39 inserido com sucesso!
# BIBB39 inserido com sucesso!
# GOAU3F inserido com sucesso!
# GOAU3F inserido com sucesso!
# COPH34 inserido com sucesso!
# COPH34 inserido com sucesso!
# EQIR11 inserido com sucesso!
# EQIR11 inserido com sucesso!
# MILS3F inserido com sucesso!
# MILS3F inserido com sucesso!
# BGWH39 inserido com sucesso!
# BGWH39 inserido com sucesso!
# APTO11 inserido com sucesso!
# APTO11 inserido com sucesso!
# MEGA3F inserido com sucesso!
# MEGA3F inserido com sucesso!
# MEAL3F inserido com sucesso!
# MEAL3F inserido com sucesso!
# TASA3F inserido com sucesso!
# TASA3F inserido com sucesso!
# INTB3F inserido com sucesso!
# INTB3F inserido com sucesso!
# HOOT4 inserido com sucesso!
# HOOT4 inserido com sucesso!
# HREC11 inserido com sucesso!
# HREC11 inserido com sucesso!
# EVEN3F inserido com sucesso!
# EVEN3F inserido com sucesso!
# SMFT3F inserido com sucesso!
# SMFT3F inserido com sucesso!
# BOBR4 inserido com sucesso!
# BOBR4 inserido com sucesso!
# MFII11 inserido com sucesso!
# MFII11 inserido com sucesso!
# DASA3F inserido com sucesso!
# DASA3F inserido com sucesso!
# CSUD3F inserido com sucesso!
# CSUD3F inserido com sucesso!
# HTMX11 inserido com sucesso!
# HTMX11 inserido com sucesso!
# RIGG34 inserido com sucesso!
# RIGG34 inserido com sucesso!
# MUTC34 inserido com sucesso!
# MUTC34 inserido com sucesso!
# BEWA39 inserido com sucesso!
# BEWA39 inserido com sucesso!
# GUAR3F inserido com sucesso!
# GUAR3F inserido com sucesso!
# LJQQ3F inserido com sucesso!
# LJQQ3F inserido com sucesso!
# PPLA11 inserido com sucesso!
# PPLA11 inserido com sucesso!
# BIDB11 inserido com sucesso!
# BIDB11 inserido com sucesso!
# XPCM11 inserido com sucesso!
# XPCM11 inserido com sucesso!
# BPAC3 inserido com sucesso!
# BPAC3 inserido com sucesso!
# BEES4 inserido com sucesso!
# BEES4 inserido com sucesso!
# PYPL34 inserido com sucesso!
# PYPL34 inserido com sucesso!
# VULC3F inserido com sucesso!
# VULC3F inserido com sucesso!
# JFEN3 inserido com sucesso!
# JFEN3 inserido com sucesso!
# CTSA3 inserido com sucesso!
# CTSA3 inserido com sucesso!
# KIVO11 inserido com sucesso!
# KIVO11 inserido com sucesso!
# TMCO34 inserido com sucesso!
# TMCO34 inserido com sucesso!
# EGAF11 inserido com sucesso!
# EGAF11 inserido com sucesso!
# PTBL3F inserido com sucesso!
# PTBL3F inserido com sucesso!
# SOJA3F inserido com sucesso!
# SOJA3F inserido com sucesso!
# BRAP3F inserido com sucesso!
# BRAP3F inserido com sucesso!
# FIQE3F inserido com sucesso!
# FIQE3F inserido com sucesso!
# VLID3F inserido com sucesso!
# VLID3F inserido com sucesso!
# TRIG11 inserido com sucesso!
# TRIG11 inserido com sucesso!
# PGCO34 inserido com sucesso!
# PGCO34 inserido com sucesso!
# TELB4 inserido com sucesso!
# TELB4 inserido com sucesso!
# BEFV39 inserido com sucesso!
# BEFV39 inserido com sucesso!
# S2HO34 inserido com sucesso!
# S2HO34 inserido com sucesso!
# VIVR3F inserido com sucesso!
# VIVR3F inserido com sucesso!
# LAVV3F inserido com sucesso!
# LAVV3F inserido com sucesso!
# Q2SC34 inserido com sucesso!
# Q2SC34 inserido com sucesso!
# RNGO11 inserido com sucesso!
# RNGO11 inserido com sucesso!
# JPPA11 inserido com sucesso!
# JPPA11 inserido com sucesso!
# INEP3F inserido com sucesso!
# INEP3F inserido com sucesso!
# ...
# T2ER34 inserido com sucesso!
# P1DD34 inserido com sucesso!
# P1DD34 inserido com sucesso!
# HCHG11 inserido com sucesso!
# HCHG11 inserido com sucesso!
# CRFF11 inserido com sucesso!
# CRFF11 inserido com sucesso!
# S2CH34 inserido com sucesso!
# S2CH34 inserido com sucesso!
# GEOO34 inserido com sucesso!
# GEOO34 inserido com sucesso!
# I1RP34 inserido com sucesso!
# I1RP34 inserido com sucesso!
# H1DB34 inserido com sucesso!
# H1DB34 inserido com sucesso!
# L1DO34 inserido com sucesso!
# L1DO34 inserido com sucesso!
# ULEV34 inserido com sucesso!
# ULEV34 inserido com sucesso!
# CRAA11 inserido com sucesso!
# CRAA11 inserido com sucesso!
# BIEI39 inserido com sucesso!
# BIEI39 inserido com sucesso!
# KMIC34 inserido com sucesso!
# KMIC34 inserido com sucesso!
# E2TS34 inserido com sucesso!
# E2TS34 inserido com sucesso!
# A1ZN34 inserido com sucesso!
# A1ZN34 inserido com sucesso!
# A1TH34 inserido com sucesso!
# A1TH34 inserido com sucesso!
# E1XC34 inserido com sucesso!
# E1XC34 inserido com sucesso!
# BURA39 inserido com sucesso!
# BURA39 inserido com sucesso!
# GSHP3F inserido com sucesso!
# GSHP3F inserido com sucesso!
# JOPA3F inserido com sucesso!
# JOPA3F inserido com sucesso!
# BRKM6F inserido com sucesso!
# BRKM6F inserido com sucesso!
# BPML11 inserido com sucesso!
# BPML11 inserido com sucesso!
# L1MN34 inserido com sucesso!
# L1MN34 inserido com sucesso!
# ACNB34 inserido com sucesso!
# ACNB34 inserido com sucesso!
# NCRI11 inserido com sucesso!
# NCRI11 inserido com sucesso!
# BNBR3F inserido com sucesso!
# BNBR3F inserido com sucesso!
# AVGO34 inserido com sucesso!
# AVGO34 inserido com sucesso!
# PHMO34 inserido com sucesso!
# PHMO34 inserido com sucesso!
# SNSY5F inserido com sucesso!
# SNSY5F inserido com sucesso!
# MACY34 inserido com sucesso!
# MACY34 inserido com sucesso!
# MGEL4F inserido com sucesso!
# MGEL4F inserido com sucesso!
# LFTT11 inserido com sucesso!
# LFTT11 inserido com sucesso!
# I1AC34 inserido com sucesso!
# I1AC34 inserido com sucesso!
# M1DB34 inserido com sucesso!
# M1DB34 inserido com sucesso!
# LASC11 inserido com sucesso!
# LASC11 inserido com sucesso!
# V2MW34 inserido com sucesso!
# V2MW34 inserido com sucesso!
# E1FX34 inserido com sucesso!
# E1FX34 inserido com sucesso!
# C2AC34 inserido com sucesso!
# C2AC34 inserido com sucesso!
# BIWM39 inserido com sucesso!
# BIWM39 inserido com sucesso!
# SIMN34 inserido com sucesso!
# SIMN34 inserido com sucesso!
# M1UF34 inserido com sucesso!
# M1UF34 inserido com sucesso!
# A1MT34 inserido com sucesso!
# A1MT34 inserido com sucesso!
# BDVD39 inserido com sucesso!
# BDVD39 inserido com sucesso!
# CGAS3F inserido com sucesso!
# CGAS3F inserido com sucesso!
# ABUD34 inserido com sucesso!
# ABUD34 inserido com sucesso!
# FZDA11 inserido com sucesso!
# FZDA11 inserido com sucesso!
# WTSP11B inserido com sucesso!
# WTSP11B inserido com sucesso!
# PRSV11 inserido com sucesso!
# PRSV11 inserido com sucesso!
# ALMI11 inserido com sucesso!
# ALMI11 inserido com sucesso!
# FAMB11B inserido com sucesso!
# FAMB11B inserido com sucesso!
# R1IN34 inserido com sucesso!
# R1IN34 inserido com sucesso!
# ASMT11 inserido com sucesso!
# ASMT11 inserido com sucesso!
# O2HI34 inserido com sucesso!
# O2HI34 inserido com sucesso!
# TRVC34 inserido com sucesso!
# TRVC34 inserido com sucesso!
# CCRF11 inserido com sucesso!
# CCRF11 inserido com sucesso!
# P2CF34 inserido com sucesso!
# P2CF34 inserido com sucesso!
# HUCG11 inserido com sucesso!
# HUCG11 inserido com sucesso!
# SNEC34 inserido com sucesso!
# SNEC34 inserido com sucesso!
# BGNO39 inserido com sucesso!
# BGNO39 inserido com sucesso!
# BLMC11 inserido com sucesso!
# BLMC11 inserido com sucesso!
# HAAA11 inserido com sucesso!
# HAAA11 inserido com sucesso!
# M1SC34 inserido com sucesso!
# M1SC34 inserido com sucesso!
# FESA3F inserido com sucesso!
# FESA3F inserido com sucesso!
# E1WL34 inserido com sucesso!
# E1WL34 inserido com sucesso!
# G1DS34 inserido com sucesso!
# G1DS34 inserido com sucesso!
# NUTR3F inserido com sucesso!
# NUTR3F inserido com sucesso!
# V1MC34 inserido com sucesso!
# V1MC34 inserido com sucesso!
# E1CO34 inserido com sucesso!
# E1CO34 inserido com sucesso!
# PHGN34 inserido com sucesso!
# PHGN34 inserido com sucesso!
# BEWY39 inserido com sucesso!
# BEWY39 inserido com sucesso!
# BGRT39 inserido com sucesso!
# BGRT39 inserido com sucesso!
# P2LT34 inserido com sucesso!
# P2LT34 inserido com sucesso!
# A1NE34 inserido com sucesso!
# A1NE34 inserido com sucesso!
# ABTT34 inserido com sucesso!
# ABTT34 inserido com sucesso!
# CTNM4F inserido com sucesso!
# CTNM4F inserido com sucesso!
# WSEC11 inserido com sucesso!
# WSEC11 inserido com sucesso!
# EAIN34 inserido com sucesso!
# EAIN34 inserido com sucesso!
# BSRE39 inserido com sucesso!
# BSRE39 inserido com sucesso!
# CXRI11 inserido com sucesso!
# CXRI11 inserido com sucesso!
# U1AL34 inserido com sucesso!
# U1AL34 inserido com sucesso!
# BLPA39 inserido com sucesso!
# BLPA39 inserido com sucesso!
# H1LT34 inserido com sucesso!
# H1LT34 inserido com sucesso!
# AGRI11 inserido com sucesso!
# AGRI11 inserido com sucesso!
# NEWU11 inserido com sucesso!
# NEWU11 inserido com sucesso!
# BOTZ39 inserido com sucesso!
# BOTZ39 inserido com sucesso!
# BPVE39 inserido com sucesso!
# BPVE39 inserido com sucesso!
# B1AX34 inserido com sucesso!
# B1AX34 inserido com sucesso!
# GEPA3F inserido com sucesso!
# GEPA3F inserido com sucesso!
# W1MG34 inserido com sucesso!
# W1MG34 inserido com sucesso!
# BSNS39 inserido com sucesso!
# BSNS39 inserido com sucesso!
# C1BS34 inserido com sucesso!
# C1BS34 inserido com sucesso!
# BLPX39 inserido com sucesso!
# BLPX39 inserido com sucesso!
# BIEM39 inserido com sucesso!
# BIEM39 inserido com sucesso!
# B1SX34 inserido com sucesso!
# B1SX34 inserido com sucesso!
# BSDV39 inserido com sucesso!
# BSDV39 inserido com sucesso!
# A1UT34 inserido com sucesso!
# A1UT34 inserido com sucesso!
# W1YN34 inserido com sucesso!
# W1YN34 inserido com sucesso!
# BHIX39 inserido com sucesso!
# BHIX39 inserido com sucesso!
# BCLO39 inserido com sucesso!
# BCLO39 inserido com sucesso!
# BMIL39 inserido com sucesso!
# BMIL39 inserido com sucesso!
# BCHQ39 inserido com sucesso!
# BCHQ39 inserido com sucesso!
# BSIL39 inserido com sucesso!
# BSIL39 inserido com sucesso!
# C2OL34 inserido com sucesso!
# C2OL34 inserido com sucesso!
# BCAT39 inserido com sucesso!
# BCAT39 inserido com sucesso!
# USBC34 inserido com sucesso!
# USBC34 inserido com sucesso!
# HBTS5F inserido com sucesso!
# HBTS5F inserido com sucesso!
# PEMA11 inserido com sucesso!
# PEMA11 inserido com sucesso!
# N1OW34 inserido com sucesso!
# N1OW34 inserido com sucesso!
# S1HW34 inserido com sucesso!
# S1HW34 inserido com sucesso!
# K1EY34 inserido com sucesso!
# K1EY34 inserido com sucesso!
# BHER39 inserido com sucesso!
# BHER39 inserido com sucesso!
# BDRI39 inserido com sucesso!
# BDRI39 inserido com sucesso!
# BSOC39 inserido com sucesso!
# BSOC39 inserido com sucesso!
# BBUG39 inserido com sucesso!
# BBUG39 inserido com sucesso!
# BCTE39 inserido com sucesso!
# BCTE39 inserido com sucesso!
# WGBA34 inserido com sucesso!
# WGBA34 inserido com sucesso!
# BEDC39 inserido com sucesso!
# BEDC39 inserido com sucesso!
# BFNX39 inserido com sucesso!
# BFNX39 inserido com sucesso!
# BQYL39 inserido com sucesso!
# BQYL39 inserido com sucesso!
# BCPX39 inserido com sucesso!
# BCPX39 inserido com sucesso!
# A1MP34 inserido com sucesso!
# A1MP34 inserido com sucesso!
# BRIP11 inserido com sucesso!
# BRIP11 inserido com sucesso!
# S1KM34 inserido com sucesso!
# S1KM34 inserido com sucesso!
# P2LN34 inserido com sucesso!
# P2LN34 inserido com sucesso!
# O1MC34 inserido com sucesso!
# O1MC34 inserido com sucesso!
# LIPR3F inserido com sucesso!
# LIPR3F inserido com sucesso!
# BEGU39 inserido com sucesso!
# BEGU39 inserido com sucesso!
# L1CA34 inserido com sucesso!
# L1CA34 inserido com sucesso!
# L1EN34 inserido com sucesso!
# L1EN34 inserido com sucesso!
# CEED3F inserido com sucesso!
# CEED3F inserido com sucesso!
# PATI4F inserido com sucesso!
# PATI4F inserido com sucesso!
# MOSC34 inserido com sucesso!
# MOSC34 inserido com sucesso!
# HOND34 inserido com sucesso!
# HOND34 inserido com sucesso!
# L1EG34 inserido com sucesso!
# L1EG34 inserido com sucesso!
# SMAB11 inserido com sucesso!
# SMAB11 inserido com sucesso!
# MNDL3F inserido com sucesso!
# MNDL3F inserido com sucesso!
# A1SN34 inserido com sucesso!
# A1SN34 inserido com sucesso!
# BILF39 inserido com sucesso!
# BILF39 inserido com sucesso!
# RBLG11 inserido com sucesso!
# RBLG11 inserido com sucesso!
# H1OG34 inserido com sucesso!
# H1OG34 inserido com sucesso!
# W1EL34 inserido com sucesso!
# W1EL34 inserido com sucesso!
# BOXP34 inserido com sucesso!
# BOXP34 inserido com sucesso!
# OGHY11 inserido com sucesso!
# OGHY11 inserido com sucesso!
# BEWQ39 inserido com sucesso!
# BEWQ39 inserido com sucesso!
# F1MC34 inserido com sucesso!
# F1MC34 inserido com sucesso!
# B1SA34 inserido com sucesso!
# B1SA34 inserido com sucesso!
# M1TT34 inserido com sucesso!
# M1TT34 inserido com sucesso!
# BMIN3F inserido com sucesso!
# BMIN3F inserido com sucesso!
# WPLZ11 inserido com sucesso!
# WPLZ11 inserido com sucesso!
# T1MU34 inserido com sucesso!
# T1MU34 inserido com sucesso!
# FLRP11 inserido com sucesso!
# FLRP11 inserido com sucesso!
# N1DA34 inserido com sucesso!
# N1DA34 inserido com sucesso!
# W1AB34 inserido com sucesso!
# W1AB34 inserido com sucesso!
# A1AP34 inserido com sucesso!
# A1AP34 inserido com sucesso!
# E1RI34 inserido com sucesso!
# E1RI34 inserido com sucesso!
# EPAR3F inserido com sucesso!
# EPAR3F inserido com sucesso!
# C1TA34 inserido com sucesso!
# C1TA34 inserido com sucesso!
# AMGN34 inserido com sucesso!
# AMGN34 inserido com sucesso!
# BSOX39 inserido com sucesso!
# BSOX39 inserido com sucesso!
# VRTX34 inserido com sucesso!
# VRTX34 inserido com sucesso!
# GPAR3F inserido com sucesso!
# GPAR3F inserido com sucesso!
# FDES11F inserido com sucesso!
# FDES11F inserido com sucesso!
# BCWV39 inserido com sucesso!
# BCWV39 inserido com sucesso!
# P1GR34 inserido com sucesso!
# P1GR34 inserido com sucesso!
# ELET5F inserido com sucesso!
# ELET5F inserido com sucesso!
# WLMM4F inserido com sucesso!
# WLMM4F inserido com sucesso!
# BRLA11 inserido com sucesso!
# BRLA11 inserido com sucesso!
# A1PA34 inserido com sucesso!
# A1PA34 inserido com sucesso!
# SBUB34 inserido com sucesso!
# SBUB34 inserido com sucesso!
# HGIC11 inserido com sucesso!
# HGIC11 inserido com sucesso!
# HSRE11 inserido com sucesso!
# HSRE11 inserido com sucesso!
# F1FI34 inserido com sucesso!
# F1FI34 inserido com sucesso!
# RPAD6F inserido com sucesso!
# RPAD6F inserido com sucesso!
# BSHY39 inserido com sucesso!
# BSHY39 inserido com sucesso!
# CEED4F inserido com sucesso!
# CEED4F inserido com sucesso!
# C1NC34 inserido com sucesso!
# C1NC34 inserido com sucesso!
# CRHP34 inserido com sucesso!
# CRHP34 inserido com sucesso!
# C2PT34 inserido com sucesso!
# C2PT34 inserido com sucesso!
# TEKA4F inserido com sucesso!
# TEKA4F inserido com sucesso!
# SNSY3F inserido com sucesso!
# SNSY3F inserido com sucesso!
# D1LR34 inserido com sucesso!
# D1LR34 inserido com sucesso!
# C1NS34 inserido com sucesso!
# C1NS34 inserido com sucesso!
# B2HI34 inserido com sucesso!
# B2HI34 inserido com sucesso!
# C1MI34 inserido com sucesso!
# C1MI34 inserido com sucesso!
# L1YV34 inserido com sucesso!
# L1YV34 inserido com sucesso!
# J1CI34 inserido com sucesso!
# J1CI34 inserido com sucesso!
# E1VE34 inserido com sucesso!
# E1VE34 inserido com sucesso!
# EKTR3F inserido com sucesso!
# EKTR3F inserido com sucesso!
# V1OD34 inserido com sucesso!
# V1OD34 inserido com sucesso!
# A1NS34 inserido com sucesso!
# A1NS34 inserido com sucesso!
# GTLG11 inserido com sucesso!
# GTLG11 inserido com sucesso!
# CRIP34 inserido com sucesso!
# CRIP34 inserido com sucesso!
# UPSS34 inserido com sucesso!
# UPSS34 inserido com sucesso!
# BPRP11 inserido com sucesso!
# BPRP11 inserido com sucesso!
# HBRH11 inserido com sucesso!
# HBRH11 inserido com sucesso!
# EBAY34 inserido com sucesso!
# EBAY34 inserido com sucesso!
# TKNO4F inserido com sucesso!
# TKNO4F inserido com sucesso!
# CNIC34 inserido com sucesso!
# CNIC34 inserido com sucesso!
# FMOF11 inserido com sucesso!
# FMOF11 inserido com sucesso!
# BBYY34 inserido com sucesso!
# BBYY34 inserido com sucesso!
# A1VB34 inserido com sucesso!
# A1VB34 inserido com sucesso!
# PRSN11B inserido com sucesso!
# PRSN11B inserido com sucesso!
# XRXB34 inserido com sucesso!
# XRXB34 inserido com sucesso!
# D1VN34 inserido com sucesso!
# D1VN34 inserido com sucesso!
# N2LY34 inserido com sucesso!
# N2LY34 inserido com sucesso!
# K1LA34 inserido com sucesso!
# K1LA34 inserido com sucesso!
# BFCG39 inserido com sucesso!
# BFCG39 inserido com sucesso!
# DBAG34 inserido com sucesso!
# DBAG34 inserido com sucesso!
# CBEE3F inserido com sucesso!
# CBEE3F inserido com sucesso!
# STZB34 inserido com sucesso!
# STZB34 inserido com sucesso!
# BOEI34 inserido com sucesso!
# BOEI34 inserido com sucesso!
# L1YG34 inserido com sucesso!
# L1YG34 inserido com sucesso!
# 5GTK11 inserido com sucesso!
# 5GTK11 inserido com sucesso!
# SCVB11 inserido com sucesso!
# SCVB11 inserido com sucesso!
# HBCR11 inserido com sucesso!
# HBCR11 inserido com sucesso!
# BMKS3 inserido com sucesso!
# BMKS3 inserido com sucesso!
# DEAI34 inserido com sucesso!
# DEAI34 inserido com sucesso!
# CSRN5F inserido com sucesso!
# CSRN5F inserido com sucesso!
# USIM6F inserido com sucesso!
# USIM6F inserido com sucesso!
# BRIV3F inserido com sucesso!
# BRIV3F inserido com sucesso!
# CRDA34 inserido com sucesso!
# CRDA34 inserido com sucesso!
# BTEK11 inserido com sucesso!
# BTEK11 inserido com sucesso!
# BREV11 inserido com sucesso!
# BREV11 inserido com sucesso!
# A1DM34 inserido com sucesso!
# A1DM34 inserido com sucesso!
# DOHL3F inserido com sucesso!
# DOHL3F inserido com sucesso!
# BEWP39 inserido com sucesso!
# BEWP39 inserido com sucesso!
# W1BD34 inserido com sucesso!
# W1BD34 inserido com sucesso!
# PEAB3F inserido com sucesso!
# PEAB3F inserido com sucesso!
# CRIV3F inserido com sucesso!
# CRIV3F inserido com sucesso!
# ATSA11 inserido com sucesso!
# ATSA11 inserido com sucesso!
# H1RL34 inserido com sucesso!
# H1RL34 inserido com sucesso!
# H2TA34 inserido com sucesso!
# H2TA34 inserido com sucesso!
# MOOO34 inserido com sucesso!
# MOOO34 inserido com sucesso!
# FRIO3F inserido com sucesso!
# FRIO3F inserido com sucesso!
# BDLL3F inserido com sucesso!
# BDLL3F inserido com sucesso!
# BDOM11 inserido com sucesso!
# BDOM11 inserido com sucesso!
# LMTB34 inserido com sucesso!
# LMTB34 inserido com sucesso!
# FIGE3F inserido com sucesso!
# FIGE3F inserido com sucesso!
# WABC34 inserido com sucesso!
# WABC34 inserido com sucesso!
# USSX34 inserido com sucesso!
# USSX34 inserido com sucesso!
# DGCO34 inserido com sucesso!
# DGCO34 inserido com sucesso!
# V1NO34 inserido com sucesso!
# V1NO34 inserido com sucesso!
# H1PE34 inserido com sucesso!
# H1PE34 inserido com sucesso!
# BAHI3F inserido com sucesso!
# BAHI3F inserido com sucesso!
# VLOE34 inserido com sucesso!
# VLOE34 inserido com sucesso!
# CRDE3F inserido com sucesso!
# CRDE3F inserido com sucesso!
# BLUR11 inserido com sucesso!
# BLUR11 inserido com sucesso!
# G1SK34 inserido com sucesso!
# G1SK34 inserido com sucesso!
# BCIR39 inserido com sucesso!
# BCIR39 inserido com sucesso!
# SOND5F inserido com sucesso!
# SOND5F inserido com sucesso!
# BIYG39 inserido com sucesso!
# BIYG39 inserido com sucesso!
# L1RC34 inserido com sucesso!
# L1RC34 inserido com sucesso!
# IAGR11 inserido com sucesso!
# IAGR11 inserido com sucesso!
# P1IO34 inserido com sucesso!
# P1IO34 inserido com sucesso!
# B1CS34 inserido com sucesso!
# B1CS34 inserido com sucesso!
# S1WK34 inserido com sucesso!
# S1WK34 inserido com sucesso!
# INGG34 inserido com sucesso!
# INGG34 inserido com sucesso!
# IGTI4F inserido com sucesso!
# IGTI4F inserido com sucesso!
# M1AA34 inserido com sucesso!
# M1AA34 inserido com sucesso!
# C2CA34 inserido com sucesso!
# C2CA34 inserido com sucesso!
# D1OV34 inserido com sucesso!
# D1OV34 inserido com sucesso!
# CSRN6F inserido com sucesso!
# CSRN6F inserido com sucesso!
# J2AZ34 inserido com sucesso!
# J2AZ34 inserido com sucesso!
# NORD3F inserido com sucesso!
# NORD3F inserido com sucesso!
# HETA4F inserido com sucesso!
# HETA4F inserido com sucesso!
# PEVC11 inserido com sucesso!
# PEVC11 inserido com sucesso!
# E1QR34 inserido com sucesso!
# E1QR34 inserido com sucesso!
# C1RR34 inserido com sucesso!
# C1RR34 inserido com sucesso!
# F1NI34 inserido com sucesso!
# F1NI34 inserido com sucesso!
# CTNM3F inserido com sucesso!
# CTNM3F inserido com sucesso!
# LOWC34 inserido com sucesso!
# LOWC34 inserido com sucesso!
# GPRO34 inserido com sucesso!
# GPRO34 inserido com sucesso!
# E1XR34 inserido com sucesso!
# E1XR34 inserido com sucesso!
# GILD34 inserido com sucesso!
# GILD34 inserido com sucesso!
# BIVW39 inserido com sucesso!
# BIVW39 inserido com sucesso!
# BXPO11 inserido com sucesso!
# BXPO11 inserido com sucesso!

# %% [markdown]
# 6.   Gera o PDF

# %%
# cria um objeto PDF
pdf = FPDF()

# adiciona uma página ao PDF
pdf.add_page()

# define o tamanho e a fonte do texto do cabeçalho
pdf.set_font('Arial', 'B', 20)

# adiciona o cabeçalho com o título
pdf.cell(0, 10, 'Desafio Programador Protheus Unoesc', 0, 1, 'C')
pdf.ln()

# define o tamanho e a fonte do texto
pdf.set_font('Arial', 'B', 16)

# abre uma conexão com o banco de dados
conn = sqlite3.connect('desafio_protheus.bd')

# busca os dados no banco de dados
cursor = conn.execute("SELECT simbolo, nome, Cotacao, ValorMercado, VolumeTransacoes, Moeda, Data FROM Acao INNER JOIN Cotacao ON Acao.idAcao = Cotacao.idAcao")

# percorre os resultados da consulta e adiciona ao PDF
for row in cursor:
    pdf.cell(40, 10, 'Símbolo: ' + row[0])
    pdf.ln()
    pdf.cell(40, 10, 'Nome: ' + row[1])
    pdf.ln()
    pdf.cell(40, 10, 'Cotação: ' + str(row[2]))
    pdf.ln()
    pdf.cell(40, 10, 'Valor de Mercado: ' + str(row[3]))
    pdf.ln()
    pdf.cell(40, 10, 'Volume de Transações: ' + str(row[4]))
    pdf.ln()
    pdf.cell(40, 10, 'Moeda: ' + row[5])
    pdf.ln()
    pdf.cell(40, 10, 'Data: ' + row[6])
    pdf.ln()
    pdf.ln()

# fecha a conexão com o banco de dados
conn.close()

# salva o PDF
pdf.output('dados.pdf', 'F')
# Out:
# ''
